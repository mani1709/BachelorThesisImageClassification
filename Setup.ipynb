# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# ...
# WARNING: You are using pip version 20.3.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Manuel\anaconda3\envs\tensorflow\python.exe -m pip install --upgrade pip' command.
# ...

# %%
# !pip list
# Out:
# Package                      Version
# WARNING: You are using pip version 20.3.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Manuel\anaconda3\envs\tensorflow\python.exe -m pip install --upgrade pip' command.
# ---------------------------- ---------
# absl-py                      1.1.0
# anyio                        3.5.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# Babel                        2.9.1
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       4.1.0
# brotlipy                     0.7.0
# cachetools                   5.2.0
# certifi                      2021.10.8
# cffi                         1.15.0
# charset-normalizer           2.0.4
# colorama                     0.4.4
# cryptography                 37.0.1
# ...
